# %%
import numpy as np
import pandas as pd

# %%
columns = ['W', 'X','Y','Z']

# %%
index = ['A','B','C','D','E']

# %%
from numpy.random import randint

# %%
np.random.seed(42)
data = randint(-100,100,(5,4))

# %%
data
# Out:
# array([[  2,  79,  -8, -86],
#        [  6, -29,  88, -80],
#        [  2,  21, -26, -13],
#        [ 16,  -1,   3,  51],
#        [ 30,  49, -48, -99]])

# %%
df = pd.DataFrame(data, index, columns)

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df['W']
# Out:
# A     2
# B     6
# C     2
# D    16
# E    30
# Name: W, dtype: int64

# %%
type(df['W']) # each column is just a panda series that you join with common indexes
# Out:
# pandas.core.series.Series

# %%
df[['W','Z']] # double brackets because a list
# Out:
#     W   Z
# A   2 -86
# B   6 -80
# C   2 -13
# D  16  51
# E  30 -99

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#     W   X   Y   Z  new
# A   2  79  -8 -86   -6
# B   6 -29  88 -80   94
# C   2  21 -26 -13  -24
# D  16  -1   3  51   19
# E  30  49 -48 -99  -18

# %%
df = df.drop('new', axis = 1)

# %%
df.loc['A']
# Out:
# W     2
# X    79
# Y    -8
# Z   -86
# Name: A, dtype: int64

# %%
df.loc[['A','E']]
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# E  30  49 -48 -99

# %%
df.iloc[0:3]
# Out:
#    W   X   Y   Z
# A  2  79  -8 -86
# B  6 -29  88 -80
# C  2  21 -26 -13

# %%
df.drop('C')
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df.loc['A','W']
# Out:
# 2

# %%
df.loc[['A','C'],['W','Y']]
# Out:
#    W   Y
# A  2  -8
# C  2 -26

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
df > 0
# Out:
#       W      X      Y      Z
# A  True   True  False  False
# B  True  False   True  False
# C  True   True  False  False
# D  True  False   True   True
# E  True   True  False  False

# %%
df[df>0]
# Out:
#     W     X     Y     Z
# A   2  79.0   NaN   NaN
# B   6   NaN  88.0   NaN
# C   2  21.0   NaN   NaN
# D  16   NaN   3.0  51.0
# E  30  49.0   NaN   NaN

# %%
df['X'] >0 # filter out X
# Out:
# A     True
# B    False
# C     True
# D    False
# E     True
# Name: X, dtype: bool

# %%
df[df['X'] >0]
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# C   2  21 -26 -13
# E  30  49 -48 -99

# %%
df[(df['W'] > 0) & (df['Y'] > 1)]
# Out:
#     W   X   Y   Z
# B   6 -29  88 -80
# D  16  -1   3  51

# %%
df.reset_index()
# Out:
#   index   W   X   Y   Z
# 0     A   2  79  -8 -86
# 1     B   6 -29  88 -80
# 2     C   2  21 -26 -13
# 3     D  16  -1   3  51
# 4     E  30  49 -48 -99

# %%
df
# Out:
#     W   X   Y   Z
# A   2  79  -8 -86
# B   6 -29  88 -80
# C   2  21 -26 -13
# D  16  -1   3  51
# E  30  49 -48 -99

# %%
new_ind = ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['States'] = new_ind

# %%
df
# Out:
#     W   X   Y   Z States
# A   2  79  -8 -86     CA
# B   6 -29  88 -80     NY
# C   2  21 -26 -13     WY
# D  16  -1   3  51     OR
# E  30  49 -48 -99     CO

# %%
df = df.set_index('States')

# %%
df
# Out:
#          W   X   Y   Z
# States
# CA       2  79  -8 -86
# NY       6 -29  88 -80
# WY       2  21 -26 -13
# OR      16  -1   3  51
# CO      30  49 -48 -99

# %%
df.columns # States is now index not column
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.describe()
# Out:
#               W          X          Y          Z
# count   5.00000   5.000000   5.000000   5.000000
# mean   11.20000  23.800000   1.800000 -45.400000
# std    11.96662  42.109381  51.915316  63.366395
# min     2.00000 -29.000000 -48.000000 -99.000000
# 25%     2.00000  -1.000000 -26.000000 -86.000000
# 50%     6.00000  21.000000  -8.000000 -80.000000
# 75%    16.00000  49.000000   3.000000 -13.000000
# max    30.00000  79.000000  88.000000  51.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, CA to CO
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       5 non-null      int64
#  1   X       5 non-null      int64
#  2   Y       5 non-null      int64
#  3   Z       5 non-null      int64
# dtypes: int64(4)
# memory usage: 200.0+ bytes

# %%
df.dtypes
# Out:
# W    int64
# X    int64
# Y    int64
# Z    int64
# dtype: object
